# %% [markdown]
# <a id='intro'></a>
# ## Introduction

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling

# %%
df = pd.read_csv('tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline      ...       \
# 0              The park is open.      ...
# 1             What a Lovely Day.      ...
# 2     One Choice Can Destroy You      ...
# 3  Every generation has a story.      ...
# 4            Vengeance Hits Home      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Data Cleaning
# #### Convert the 'release_date' column to datetime
# > Parsing the column using the typical parse_dates argument of pd.read_csv or the pd.to_datetime function does not work properly. The reason being that the column contains years in the 1900s, and Python assumes all years are in the 21st century, resulting in incorrectly parsed future years. I will have to correctly identify and fix the problematic years before parsing the column.
# * Create a boolean mask to locate problematic years
# * Correctly label the dates
# * Parse the column to datetime
#
# #### Columns to drop
# > I will drop the __budget__ and __revenue__ columns and use their adjusted values instead
#
# > I will drop all null values
#
# > I will drop rows with zeros in relevant columns I will be analysing
# * __vote_average__, __budget__, __revenue__
#
# > I will drop all columns except for the following, which I will be using for my analysis:
# * [__original_title__, __cast__, __director__, __genres__, __production_companies__, __release_date__, __vote_average__, __release_year__, __budget__]

# %%
# Python does not properly parse certain years (ex: 1-1-66 gets parsed as 2066-1-1)
# Include a '19' in front of all years in the 1900's to clearly indicate the century
from datetime import datetime

# Boolean mask for years in the 1900's
incorrect_dates = df['release_year'] < 2000
# Correct the dates
df.loc[incorrect_dates,'release_date'] = df[incorrect_dates]['release_date'].apply(lambda x: x[:-2] + '19' + x[-2:])
# Parse release_date column
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
# Drop budget and revenue column
df.drop(columns=['budget','revenue'], inplace=True)
# Rename budget_adj column to budget
df.rename(columns={'budget_adj':'budget','revenue_adj':'revenue'}, inplace=True)

# Change all values of 'nan' to null values, then drop rows with null values
df.replace('nan', np.nan, inplace=True)
df.dropna(inplace=True)

# Drop rows with zeros in relevant columns
df = df.loc[df[['vote_average','budget','revenue']].ne(0).all(axis=1)]

# List of columns to keep ['original_title','cast','director','genres','production_companies','release_date','vote_average','release_year','budget']
keep_list = ['original_title','cast','director','genres','production_companies','release_date','vote_average','budget','revenue']

# Update DataFrame
df = df[keep_list]

df.head()
# Out:
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13
# 2  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18
# 3          Lucasfilm|Truenorth Productions|Bad Robot   2015-12-15
# 4  Universal Pictures|Original Film|Media Rights ...   2015-04-01
#
#    vote_average        budget       revenue
# 0           6.5  1.379999e+08  1.392446e+09
# 1           7.1  1.379999e+08  3.481613e+08
# 2           6.3  1.012000e+08  2.716190e+08
# 3           7.5  1.839999e+08  1.902723e+09
# 4           7.3  1.747999e+08  1.385749e+09

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %% [markdown]
# ### Which months are the best times to view movies?
# #### Description:
# > Determine which months have the highest average rating, view the median number of movies released each month, and determine the average budget for movies by their release month.
#
# #### Procedure:
# >
# 1. Plot the average rating vs. release month
#   1. Create a copy of the DataFrame and name it __rating_by_month__
#   2. Convert the __release_date__ column to numerical representations of the month
#   3. Group by __release_date__, then find the mean of the __vote_average__, and plot the values
# 2. Plot the median number of movies each month
#   1. Create a copy of the DataFrame with the index set to __release_date__ and name it __monthly_count__
#   2. Resample the __monthly_count__ DataFrame by month, and count the number of movies that appear each month
#   3. Drop the months with zero movies
#   4. Reset the index
#   5. Convert the __release_date__ column to numerical representations of the month
#   6. Group by __release_date__, then find the median number of movies for each month, and plot as a bar chart
# 3. Plot the average budget vs. release_month
#   1. Create a copy of the DataFrame and name it __budget_info__
#   2. Convert the __release_date__ column to numerical representations of the month
#   3. Group by __release_date__, then find the mean of the __budget__, and plot the values

# %% [markdown]
# ##### 1. Plot the average rating vs. release month
# ##### 2. Plot the median number of movies each month
# ##### 3. Plot the average budget vs. release_month

# %%
# Plot the average rating vs. release month
plt.figure
rating_by_month = df.copy()
rating_by_month['release_date'] = rating_by_month['release_date'].dt.month
rating_by_month.groupby('release_date')['vote_average'].mean().plot(figsize=(10,5))
plt.subplots_adjust(left = 0.145)
plt.title('Average Rating vs. Release Month')
plt.xlabel('Release Month')
plt.ylabel('Average Rating')
plt.show()

# Plot the median number of movies each month
plt.figure
monthly_count = df.set_index('release_date')
monthly_count = monthly_count.resample('M').count()
monthly_count = monthly_count.loc[monthly_count.ne(0).all(axis=1)]
monthly_count = monthly_count.reset_index()
monthly_count['release_date'] = monthly_count['release_date'].dt.month
standout = ['grey','grey','gray','grey','b','b','b','grey','b','b','b','b']
monthly_count.groupby('release_date')['original_title'].median().plot(kind='bar', color=standout, figsize=(10,5))
plt.title('Median Number of Movies Released Each Month')
plt.xlabel('Release Month')
plt.ylabel('Number of Movies')
plt.show()

# Plot the average budget vs. release_month
plt.figure
budget_info = df.copy()
budget_info['release_date'] = budget_info['release_date'].dt.month
budget_info.groupby('release_date')['budget'].mean().plot(figsize=(10,5))
plt.title('Average Budget vs. Release Month')
plt.xlabel('Release Month')
plt.ylabel('Average Budget');

# %% [markdown]
# ### Which actors, directors, and production companies produce the best movies by genre?
# #### Description:
# > I would like to find the top 10 actors/directors/production_companies by genre.
#
# #### Procedure:
# >
# 1. Preliminary steps:
#   1. Write a function to expand each of these columns, as each row contains multiple values
#   2. Expand the columns
# 2. Find the top 10 actors by genre
#   1. Group by the __genres__ and __cast__ column, then find the mean of the __vote_average__ column
#   2. Take the previous groupby object, groupby the __genres__ colum, then find the top 10 values from the __vote_average__ column
# 3. Find the top 10 directors by genre
#   1. Group by the __genres__ and __director__ column, then find the mean of the __vote_average__ column
#   2. Take the previous groupby object, groupby the __genres__ colum, then find the top 10 values from the __vote_average__
# 4. Find the top 10 production companies by genre
#   1. Group by the __genres__ and __production_companies__ column, then find the mean of the __vote_average__ column
#   2. Take the previous groupby object, groupby the __genres__ colum, then find the top 10 values from the __vote_average__

# %% [markdown]
# ##### 1. Preliminary steps:

# %%
# Function to expand columns with multiple values
def expand(df_in, column, sep='|'):
    """
    # !!! IMPORTANT !!! : 
        df_in MUST HAVE NO NULL VALUES
    # !!! IMPORTANT !!!
    
    Split the values of a column and expand so the new
    DataFrame has one row per value.
    """
    indexes = list()
    new_values = list()
    # Find all rows, and column values to expand
    for i, presplit in enumerate(df_in[column]):
        # Expand the column values and store
        values = presplit.split(sep)
        new_values += values
        # Duplicate the row index and store
        indexes += [i] * len(values)
    # Copy of the original DataFrame with duplicate
     # rows to match expanded column
    df_out = df_in.iloc[indexes, :].copy()
    # Replace the column with the expanded values
    df_out[column] = new_values
    # Renumber the index
    df_out.index = list(range(len(df_out)))
    
    return df_out

# %%
# Test to see it can properly expand the columns

# Columns to expand
expand_columns = ['cast','director', 'genres','production_companies']

# Create a new dataframe
test = df.copy()
# Loop through all columns
count = 0
for column in expand_columns:
    test = expand(test,column)
    if not test[column].str.contains("\|").any():
        count += 1
    # Check to see it worked
    # Should print, "Properly expanded!"
    if count == 4:
        print('Properly expanded!')
# Out:
# Properly expanded!

# %%
# Expand the genres column, and store in a new DataFrame
expand_genres = expand(df.copy(), 'genres')

# Create a new DataFrame for each attribute and expand the corresponding column
cast_genres = expand(expand_genres, 'cast')
dir_genres = expand(expand_genres, 'director')
prod_genres = expand(expand_genres, 'production_companies')

# Create a list of all the genres
genres_list = sorted(list(expand_genres['genres'].unique()))

# %% [markdown]
# ##### 2. Find the top 10 actors by genre

# %%
# Find the top 10 actors by genre
cast_averages = pd.DataFrame(cast_genres.groupby(['genres', 'cast'])['vote_average'].mean())
find_top_10 = cast_averages['vote_average'].groupby(level=0, group_keys=False)
top_10_cast = pd.DataFrame(find_top_10.nlargest(10)).reset_index()

for genre in genres_list:
    print(top_10_cast.loc[top_10_cast['genres'] == genre])
    print('\n')
# Out:
#    genres                cast  vote_average
# 0  Action        Heath Ledger      8.100000
# 1  Action       Alec Guinness      7.900000
# 2  Action     Anthony Daniels      7.900000
# 3  Action  Billy Dee Williams      7.900000
# 4  Action       Dave Bautista      7.900000
# 5  Action   Leonardo DiCaprio      7.900000
# 6  Action       Peter Cushing      7.900000
# 7  Action     Viggo Mortensen      7.833333
# 8  Action       Carrie Fisher      7.800000
# 9  Action    Carrie-Anne Moss      7.800000
#
#
#        genres                 cast  vote_average
# 10  Adventure  Matthew McConaughey      8.000000
# 11  Adventure        Alec Guinness      7.900000
# 12  Adventure      Anthony Daniels      7.900000
# 13  Adventure   Billy Dee Williams      7.900000
# 14  Adventure        Dave Bautista      7.900000
# 15  Adventure           Ellen Page      7.900000
# 16  Adventure        Peter Cushing      7.900000
# 17  Adventure            Liv Tyler      7.833333
# 18  Adventure        Carrie Fisher      7.800000
# 19  Adventure        Daniel Henney      7.800000
#
#
#        genres            cast  vote_average
# 20  Animation     Amy Poehler           8.0
# 21  Animation     Lewis Black           8.0
# 22  Animation   Phyllis Smith           8.0
# 23  Animation    Richard Kind           8.0
# 24  Animation   Daniel Henney           7.8
# 25  Animation     Jamie Chung           7.8
# 26  Animation     Ryan Potter           7.8
# 27  Animation     Scott Adsit           7.8
# 28  Animation     T.J. Miller           7.8
# 29  Animation  Cate Blanchett           7.7
#
#
#     genres               cast  vote_average
# 30  Comedy        Lewis Black           8.0
# 31  Comedy       Richard Kind           8.0
# 32  Comedy      Kyle Chandler           7.9
# 33  Comedy  Leonardo DiCaprio           7.9
# 34  Comedy         Rob Reiner           7.9
# 35  Comedy         Aamir Khan           7.8
# 36  Comedy        Boman Irani           7.8
# 37  Comedy     Crispin Glover           7.8
# 38  Comedy      Daniel Henney           7.8
# 39  Comedy        Jamie Chung           7.8
#
#
#    genres                   cast  vote_average
# 40  Crime             James Caan           8.3
# 41  Crime          Marlon Brando           8.3
# 42  Crime  Richard S. Castellano           8.3
# 43  Crime          Robert Duvall           8.3
# 44  Crime          Aaron Eckhart           8.1
# 45  Crime           Heath Ledger           8.1
# 46  Crime            Bonnie Hunt           8.0
# 47  Crime          Gabriel Byrne           8.0
# 48  Crime         James Cromwell           8.0
# 49  Crime           Kevin Pollak           8.0
#
#
#          genres                cast  vote_average
# 50  Documentary           Vik Muniz           7.8
# 51  Documentary        Barack Obama           7.6
# 52  Documentary     Jonathan Alpert           7.6
# 53  Documentary          Matt Damon           7.6
# 54  Documentary      William Ackman           7.6
# 55  Documentary  Constantino Romero           7.5
# 56  Documentary    James Earl Jones           7.5
# 57  Documentary        Ken Watanabe           7.5
# 58  Documentary     Patrick Stewart           7.5
# 59  Documentary        Ulrich Tukur           7.5
#
#
#    genres                   cast  vote_average
# 60  Drama  Richard S. Castellano          8.30
# 61  Drama         Austin Stowell          8.20
# 62  Drama           Jayson Blair          8.20
# 63  Drama        Melissa Benoist          8.20
# 64  Drama        Jonathan Sagall          8.10
# 65  Drama              Meat Loaf          8.10
# 66  Drama          Marlon Brando          8.05
# 67  Drama            Allen Leech          8.00
# 68  Drama           Avery Brooks          8.00
# 69  Drama       Beverly D'Angelo          8.00
#
#
#     genres           cast  vote_average
# 70  Family    Amy Poehler           8.0
# 71  Family    Lewis Black           8.0
# 72  Family  Phyllis Smith           8.0
# 73  Family   Richard Kind           8.0
# 74  Family  Daniel Henney           7.8
# 75  Family    Jamie Chung           7.8
# 76  Family    Ryan Potter           7.8
# 77  Family    Scott Adsit           7.8
# 78  Family    T.J. Miller           7.8
# 79  Family   Alan Rickman           7.7
#
#
#      genres             cast  vote_average
# 80  Fantasy      Bonnie Hunt      8.000000
# 81  Fantasy   James Cromwell      8.000000
# 82  Fantasy        Liv Tyler      7.833333
# 83  Fantasy  Viggo Mortensen      7.833333
# 84  Fantasy     Alan Rickman      7.700000
# 85  Fantasy     Kristen Wiig      7.700000
# 86  Fantasy        Eric Idle      7.600000
# 87  Fantasy   Graham Chapman      7.600000
# 156  Thriller          Kevin Pollak           8.0
# 157  Thriller          Rory Kinnear           8.0
# 158  Thriller         Sean Bridgers           8.0
# 159  Thriller       Stephen Baldwin           8.0
# 160  Thriller           Carrie Coon           7.9
#
#
#     genres              cast  vote_average
# 161    War      Ben Kingsley           8.1
# 162    War  Caroline Goodall           8.1
# 163    War   Jonathan Sagall           8.1
# 164    War       Liam Neeson           8.1
# 165    War       Allen Leech           8.0
# 166    War   Keira Knightley           8.0
# 167    War     Matthew Goode           8.0
# 168    War      Rory Kinnear           8.0
# 169    War      Adrien Brody           7.9
# 170    War        Emilia Fox           7.9
#
#
#       genres                  cast  vote_average
# 171  Western       Christoph Waltz          7.70
# 172  Western            Jamie Foxx          7.70
# 173  Western      Kerry Washington          7.70
# 174  Western     Samuel L. Jackson          7.55
# 175  Western     Leonardo DiCaprio          7.45
# 176  Western        DemiÃ¡n Bichir          7.40
# 177  Western  Jennifer Jason Leigh          7.40
# 178  Western          Kurt Russell          7.40
# 179  Western      Domhnall Gleeson          7.20
# 180  Western         Paul Anderson          7.20

# %% [markdown]
# ##### 3. Find the top 10 directors by genre

# %%
# Find the top 10 directors by genre
dir_averages = pd.DataFrame(dir_genres.groupby(['genres', 'director'])['vote_average'].mean())
find_top_10 = dir_averages['vote_average'].groupby(level=0, group_keys=False)
top_10_dir = pd.DataFrame(find_top_10.nlargest(10)).reset_index()

for genre in genres_list:
    print(top_10_dir.loc[top_10_dir['genres'] == genre])
    print('\n')
# Out:
#    genres           director  vote_average
# 0  Action     Chris Williams           7.8
# 1  Action           Don Hall           7.8
# 2  Action   Richard Marquand           7.8
# 3  Action  Christopher Nolan           7.7
# 4  Action       Dean DeBlois           7.7
# 5  Action      Anthony Russo           7.6
# 6  Action     Gavin O'Connor           7.6
# 7  Action          Joe Russo           7.6
# 8  Action      Peter Jackson           7.6
# 9  Action         Doug Liman           7.4
#
#
#        genres           director  vote_average
# 10  Adventure  Christopher Nolan          7.95
# 11  Adventure         James Gunn          7.90
# 12  Adventure           Don Hall          7.80
# 13  Adventure   Richard Marquand          7.80
# 14  Adventure          Sean Penn          7.70
# 15  Adventure      Anthony Russo          7.60
# 16  Adventure       Bob Peterson          7.60
# 17  Adventure       Bryan Singer          7.60
# 18  Adventure          Joe Russo          7.60
# 19  Adventure        Pete Docter          7.60
#
#
#        genres      director  vote_average
# 20  Animation   Rob Minkoff      7.700000
# 21  Animation   Pete Docter      7.633333
# 22  Animation  Bob Peterson      7.600000
# 23  Animation  Dean DeBlois      7.550000
# 24  Animation  Jennifer Lee      7.500000
# 25  Animation  Wes Anderson      7.500000
# 26  Animation   Lee Unkrich      7.350000
# 27  Animation      Don Hall      7.300000
# 28  Animation   Jan Pinkava      7.300000
# 29  Animation  Nathan Greno      7.300000
#
#
#     genres         director  vote_average
# 30  Comedy  Martin Scorsese      7.900000
# 31  Comedy         Don Hall      7.800000
# 32  Comedy  Rajkumar Hirani      7.800000
# 33  Comedy     Dean DeBlois      7.700000
# 34  Comedy      Pete Docter      7.633333
# 35  Comedy     Bob Peterson      7.600000
# 36  Comedy        Joel Coen      7.600000
# 37  Comedy   Matthew Vaughn      7.600000
# 38  Comedy    Terry Gilliam      7.600000
# 39  Comedy      Terry Jones      7.600000
#
#
#    genres             director  vote_average
# 40  Crime         Bryan Singer      8.000000
# 41  Crime       Frank Darabont      8.000000
# 42  Crime     Denis Villeneuve      7.800000
# 43  Crime   Giuseppe Tornatore      7.700000
# 44  Crime    Christopher Nolan      7.633333
# 45  Crime           Dan Gilroy      7.600000
# 46  Crime            Joel Coen      7.600000
# 47  Crime       Matthew Vaughn      7.600000
# 48  Crime      Martin Scorsese      7.500000
# 49  Crime  Richard LaGravenese      7.500000
#
#
#          genres             director  vote_average
# 50  Documentary          Lucy Walker          7.80
# 51  Documentary     Charles Ferguson          7.60
# 52  Documentary  Alastair Fothergill          7.50
# 53  Documentary        Mark Linfield          7.50
# 54  Documentary      Kevin Macdonald          7.30
# 55  Documentary         Zillah Bowes          7.30
# 56  Documentary          Wim Wenders          7.20
# 57  Documentary        Michael Moore          7.05
# 58  Documentary       Eugene Jarecki          6.70
# 59  Documentary          Heidi Ewing          6.70
#
#
#    genres            director  vote_average
# 60  Drama     Damien Chazelle          8.20
# 61  Drama        Bryan Singer          8.00
# 62  Drama      Frank Darabont          8.00
# 63  Drama    Lenny Abrahamson          8.00
# 64  Drama       Morten Tyldum          8.00
# 65  Drama           Tony Kaye          8.00
# 66  Drama    Denis Villeneuve          7.80
# 67  Drama     Rajkumar Hirani          7.80
# 68  Drama   Christopher Nolan          7.74
# 69  Drama  Giuseppe Tornatore          7.70
#
#
#     genres      director  vote_average
# 70  Family   Rob Minkoff      7.700000
# 71  Family   Pete Docter      7.633333
# 72  Family  Bob Peterson      7.600000
# 73  Family  Billy Wilder      7.500000
# 74  Family  Jennifer Lee      7.500000
# 75  Family  Wes Anderson      7.500000
# 76  Family  Dean DeBlois      7.400000
# 77  Family   David Yates      7.400000
# 78  Family   Lee Unkrich      7.350000
# 79  Family      Don Hall      7.300000
#
#
#      genres            director  vote_average
# 80  Fantasy      Frank Darabont          8.00
# 81  Fantasy      James McTeigue          7.60
# 82  Fantasy         Terry Jones          7.60
# 83  Fantasy        Dean DeBlois          7.55
# 84  Fantasy  Christopher Miller          7.50
# 85  Fantasy         J.J. Abrams          7.50
# 86  Fantasy        Mark Osborne          7.50
# 87  Fantasy           Phil Lord          7.50
# 88  Fantasy         David Yates          7.40
# 89  Fantasy           Brad Bird          7.30
#
#
#      genres     director  vote_average
# 90  Foreign  Lucy Walker           7.8
#
#
#       genres           director  vote_average
# 91   History   Steven Spielberg           8.1
# 92   History      Morten Tyldum           8.0
# 93   History       Tom McCarthy           7.8
# 94   History         Tom Hooper           7.4
# 95   History       Terry George           7.2
# 96   History       Gus Van Sant           7.1
# 97   History       Rob Marshall           7.1
# 98   History  Jean-Marc VallÃ©e           6.9
# 99   History    Martin Scorsese           6.9
# 100  History      Oren Moverman           6.9
#
#
#      genres          director  vote_average
# 101  Horror      Ridley Scott      7.600000
# 102  Horror  Steven Spielberg      7.300000
# 103  Horror  William Friedkin      7.200000
# 104  Horror       Jim Sharman      7.100000
# 105  Horror   Ruben Fleischer      7.100000
# 176  Western                   James Mangold          6.80
# 177  Western                      Sngmoo Lee          6.40
# 178  Western                  Gore Verbinski          6.25
# 179  Western                    John Sanford          5.80
# 180  Western                 Martin Campbell          5.80

# %% [markdown]
# ##### 4. Find the top 10 production companies by genre

# %%
# Find the top 10 production companies by genre
prod_averages = pd.DataFrame(prod_genres.groupby(['genres', 'production_companies'])['vote_average'].mean())
find_top_10 = prod_averages['vote_average'].groupby(level=0, group_keys=False)
top_10_prod = pd.DataFrame(find_top_10.nlargest(10)).reset_index()

for genre in genres_list:
    print(top_10_prod.loc[top_10_prod['genres'] == genre])
    print('\n')
# Out:
#    genres                               production_companies  vote_average
# 0  Action                                  Bulletproof Cupid           7.9
# 1  Action                        Groucho II Film Partnership           7.8
# 2  Action                            The Saul Zaentz Company           7.8
# 3  Action                      Walt Disney Animation Studios           7.8
# 4  Action                               3 Arts Entertainment           7.7
# 5  Action                           Mad Hatter Entertainment           7.7
# 6  Action  Province of British Columbia Production Servic...           7.7
# 7  Action                                  Visiona Romantica           7.7
# 8  Action                                          Viz Media           7.7
# 9  Action                                  Zehnte Babelsberg           7.7
#
#
#        genres       production_companies  vote_average
# 10  Adventure     Lynda Obst Productions           8.0
# 11  Adventure          Bulletproof Cupid           7.9
# 12  Adventure    The Saul Zaentz Company           7.8
# 13  Adventure     Art Linson Productions           7.7
# 14  Adventure              Into the Wild           7.7
# 15  Adventure          Paramount Vantage           7.7
# 16  Adventure   River Road Entertainment           7.7
# 17  Adventure         Cloudy Productions           7.6
# 18  Adventure      International Traders           7.6
# 19  Adventure  Michael White Productions           7.6
#
#
#        genres                 production_companies  vote_average
# 20  Animation  Walt Disney Studios Motion Pictures          8.00
# 21  Animation             Mad Hatter Entertainment          7.55
# 22  Animation          American Empirical Pictures          7.50
# 23  Animation                           CityMation          7.50
# 24  Animation                    Indian Paintbrush          7.50
# 25  Animation                         Lin Pictures          7.50
# 26  Animation                     On Entertainment          7.50
# 27  Animation                           Onyx Films          7.50
# 28  Animation                       Orange Studios          7.50
# 29  Animation                       Zippcast Films          7.50
#
#
#     genres                 production_companies  vote_average
# 30  Comedy  Walt Disney Studios Motion Pictures           8.0
# 31  Comedy                           Appian Way           7.9
# 32  Comedy                    EMJAG Productions           7.9
# 33  Comedy                  Sikelia Productions           7.9
# 34  Comedy       Vidhu Vinod Chopra Productions           7.8
# 35  Comedy             Mad Hatter Entertainment           7.7
# 36  Comedy                   Cloudy Productions           7.6
# 37  Comedy                           Marv Films           7.6
# 38  Comedy            Michael White Productions           7.6
# 39  Comedy                             Moonrise           7.6
#
#
#    genres       production_companies  vote_average
# 40  Crime         Alfran Productions           8.3
# 41  Crime  Bad Hat Harry Productions           8.0
# 42  Crime    Blue Parrot Productions           8.0
# 43  Crime      Darkwoods Productions           8.0
# 44  Crime       Cecchi Gori Pictures           7.9
# 45  Crime          EMJAG Productions           7.9
# 46  Crime                   Juno Pix           7.9
# 47  Crime       Red Granite Pictures           7.9
# 48  Crime        Sikelia Productions           7.9
# 49  Crime           8:38 Productions           7.8
#
#
#          genres              production_companies  vote_average
# 50  Documentary                   Almega Projects           7.8
